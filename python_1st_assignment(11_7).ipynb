# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan-Hafizi/Assignments/blob/main/python_1st_assignment(11_7).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment Data Science Tools

# %% [markdown]
# ## **Muhammad Farhan Hafizi bin Abdul Rodzi**
#
# Data Analyst

# %% [markdown]
# *I want to be data analyst because I want to change my career path. Besides that, I see many opportunities to be data analyst in a various of industry.*

# %%
M=5
F=3
H=M*F
print(H)
# Out:
# 15

# %% [markdown]
# Menu Recommendation for Birthday Party
# 1.   Koktel buah
# 2.   Iced lemon tea
# 3. Dadih blueberry
#
# *   Makaroni goreng
# *   Fries
# *   Nugget
# *   Sausage
#
# ![download (4).jpeg](data:image/jpeg;base64,...)

# %%
import pandas as pd
df=pd.read_csv('custcat.csv')
df.head(15)
# Out:
#     region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0        2      13   44        1        9    64.0   4       5     0.0       0
# 1        3      11   33        1        7   136.0   5       5     0.0       0
# 2        3      68   52        1       24   116.0   1      29     0.0       1
# 3        2      33   33        0       12    33.0   2       0     0.0       1
# 4        2      23   30        1        9    30.0   1       2     0.0       0
# 5        2      41   39        0       17    78.0   2      16     0.0       1
# 6        3      45   22        1        2    19.0   2       4     0.0       1
# 7        2      38   35        0        5    76.0   2      10     0.0       0
# 8        3      45   59        1        7   166.0   4      31     0.0       0
# 9        1      68   41        1       21    72.0   1      22     0.0       0
# 10       2       5   33        0       10   125.0   4       5     0.0       1
# ...
